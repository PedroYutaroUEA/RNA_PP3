# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroYutaroUEA/RNA_PP3/blob/main/PP3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Redes Neurais Artificiais 2025.2
#
# - **Disciplina**: Redes Neurais Artificiais 2025.2
# - **Professora**: Elloá B. Guedes (ebgcosta@uea.edu.br)
# - **Github**: http://github.com/elloa

# %% [markdown]
# # Definição do problema

# %% [markdown]
# O seguinte trabalho visa resolver o problema de classificar a qualidade de rações caninas com base nos seus valores nutricionais.

# %% [markdown]
# # Importação das Bibliotecas

# %%
import pandas as pd
import numpy as np
import kagglehub
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. Coleta e preparação dos dados

# %% [markdown]
# Importação da base de dados:

# %%
dataset_path = ""
path = kagglehub.dataset_download(dataset_path)

print("Path to dataset files:", path)
print("Arquivos disponíveis:", os.listdir(path))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3976022335.py in <cell line: 0>()
#       1 dataset_path = ""
# ----> 2 path = kagglehub.dataset_download(dataset_path)
#       3
#       4 print("Path to dataset files:", path)
#       5 print("Arquivos disponíveis:", os.listdir(path))
#
# /usr/local/lib/python3.12/dist-packages/kagglehub/datasets.py in dataset_download(handle, path, force_download)
#      39         A string requesting the path to the requested dataset files.
#      40     """
# ---> 41     h = parse_dataset_handle(handle)
#      42     logger.info(f"Downloading Dataset: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
#      43     path, _ = registry.dataset_resolver(h, path, force_download=force_download)
#
# /usr/local/lib/python3.12/dist-packages/kagglehub/handle.py in parse_dataset_handle(handle)
#     159
#     160     msg = f"Invalid dataset handle: {handle}"
# --> 161     raise ValueError(msg)
#     162
#     163
#
# ValueError: Invalid dataset handle:

# %% [markdown]
# Visualização da base de dados:

# %%
filename = ""
df = pd.read_csv(os.path.join(path, filename))

# %%
df.head(10)

# %% [markdown]
# Verificação de dados faltantes

# %%
print(f"Numero de dados faltantes: {df.isnull().sum()}")

# %% [markdown]
# # 2. Análise Exploratória da base de dados

# %% [markdown]
# Analise preliminar dos dados

# %% [markdown]
# # 3. Determinação da tarefa de Aprendizado de Máquina

# %% [markdown]
# # 4. Determinação da abordagem de validação cruzada

# %% [markdown]
# Justificativa que corrobore com a situação:

# %% [markdown]
# ## 4.1. Determinação das Métricas de desempenho

# %% [markdown]
# Justificativa que corrobore com a situação:

# %% [markdown]
# # 5. Elaboração da Grade de busca

# %% [markdown]
# Justificativa

# %% [markdown]
# ## 5.1. Definição dos Parâmetros

# %% [markdown]
# Justificativa

# %% [markdown]
# ## 5.2. Definição dos Hiperparâmetros

# %% [markdown]
# Justificativa

# %% [markdown]
# # 6. Treinamento dos modelos

# %% [markdown]
# ## 6.1. Testando os modelos

# %% [markdown]
# # 7. Análise de desempenho dos modelos

# %% [markdown]
# ## 7.1. Análise Quantitativa

# %% [markdown]
# ## 7.2. Análise Qualitativa
